# %%
#Importing Library
import pandas as pd

# %%
#importing dataset
dataset=pd.read_csv("PrePlacement.csv")

# %%
#viewing dataset
dataset
# Out:
#      Unnamed: 0  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0             0      1      M  67.00   Others  91.00   Others  Commerce
# 1             1      2      M  79.33  Central  78.33   Others   Science
# 2             2      3      M  65.00  Central  68.00  Central      Arts
# 3             3      4      M  56.00  Central  52.00  Central   Science
# 4             4      5      M  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210         210    211      M  80.60   Others  82.00   Others  Commerce
# 211         211    212      M  58.00   Others  60.00   Others   Science
# 212         212    213      M  67.00   Others  67.00   Others  Commerce
# 213         213    214      F  74.00   Others  66.00   Others  Commerce
# 214         214    215      M  62.00  Central  58.00   Others   Science
#
#      degree_p   degree_t workex  etest_p specialisation  mba_p      status  \
# ...

# %%
#importing matplotlib
import matplotlib.pyplot as plt

# %%
# Scatter plot of etest_p vs salary
#Analyzing the scatter plot can provide insights into the relationship between "mba_p" and "salary" 
#help to identify outliers in the data.
plt.scatter(dataset['mba_p'], dataset['salary'])
plt.xlabel('mba_p')
plt.ylabel('salary')
plt.title('mba_p vs salary')
plt.show()

# %% [markdown]
# Assignment Question : plot any useful graph and explain it.

# %% [markdown]
# Resolution :  The scatter plot shows the relationship between the "mba_p" and the "salary". Each point represents an individual's mba_p score and salary. By observing the plot, we could see there is outlier in salary and most of them are having a salary in between 200000 to 400000
