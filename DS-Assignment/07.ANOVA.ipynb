# %%
#Importing Library
import pandas as pd

# %%
#importing dataset
dataset=pd.read_csv("PrePlacement.csv")

# %%
#viewing dataset
dataset
# Out:
#      Unnamed: 0  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0             0      1      M  67.00   Others  91.00   Others  Commerce
# 1             1      2      M  79.33  Central  78.33   Others   Science
# 2             2      3      M  65.00  Central  68.00  Central      Arts
# 3             3      4      M  56.00  Central  52.00  Central   Science
# 4             4      5      M  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210         210    211      M  80.60   Others  82.00   Others  Commerce
# 211         211    212      M  58.00   Others  60.00   Others   Science
# 212         212    213      M  67.00   Others  67.00   Others  Commerce
# 213         213    214      F  74.00   Others  66.00   Others  Commerce
# 214         214    215      M  62.00  Central  58.00   Others   Science
#
#      degree_p   degree_t workex  etest_p specialisation  mba_p      status  \
# ...

# %%
#to test the Analysis of Variance between etest_p and mba_p
import scipy.stats as stats
stats.f_oneway(dataset["etest_p"],dataset["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#Since the p-value is greater than the significance level of 0.05, we fail to reject the null hypothesis. 
#reject null hypothesis P<0.05
#accept null hypothesis P>0.05

# %% [markdown]
# Assignment Question : Test the Analysis of Variance between etest_p and mba_p at signifancelevel 5%.(Make decision using Hypothesis Testing)

# %% [markdown]
# Resolution :  By using above code, we found pvalue=4.67. Since the p-value is greater than the significance level of 0.05, we fail to reject the null hypothesis.
